# %%
from hotspot_getisord import getishotspot
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
##Simulate 10000 Random Uniform Points

# %%
x = np.random.uniform(0,10000,10000)
y = np.random.uniform(0,10000,10000)
uniformpoints=np.column_stack((x,y))

# %%
fig = plt.figure(figsize=(10,10))
plt.scatter(x,y,color='grey',alpha=0.1)

# %%
 #Hotspot Calculation with Box size 500 and NB degree=1

# %%
getishotspot.detect_hotspot(500,uniformpoints)
# Out:
#                    Sample Boxsize Prop_Z_0to1 Prop_Z_1to2 Prop_Z_2to3  \
# 0  Simulated Distribution     500    0.127424    0.113573    0.127424
#
#   Prop_Z_gte3 Prop_Z_gte4 Prop_Z_gte5
# 0    0.631579    0.562327    0.457064

# %%
getishotspot.hotspot_plots(500,uniformpoints)

# %%
 #Hotspot Calculation with Box size 200 and NB degree=2

# %%
getishotspot.detect_hotspot(200,uniformpoints)
# Out:
#                    Sample Boxsize Prop_Z_0to1 Prop_Z_1to2 Prop_Z_2to3  \
# 0  Simulated Distribution     200    0.285479    0.315182    0.138614
#
#   Prop_Z_gte3 Prop_Z_gte4 Prop_Z_gte5
# 0    0.260726    0.145215   0.0907591

# %%
getishotspot.hotspot_plots(200,uniformpoints)

# %%
 #Hotspot Calculation with Box size 100 and NB degree=4

# %%
getishotspot.detect_hotspot(100,uniformpoints)
# Out:
#                    Sample Boxsize Prop_Z_0to1 Prop_Z_1to2 Prop_Z_2to3  \
# 0  Simulated Distribution     100    0.659091    0.272727   0.0454545
#
#   Prop_Z_gte3 Prop_Z_gte4 Prop_Z_gte5
# 0   0.0227273   0.0151515           0

# %%
getishotspot.hotspot_plots(100,uniformpoints)
